# %% [markdown]
# 	1041
# Robot Bounded In Circle	55.1%	Medium
# 1335
# Minimum Difficulty of a Job Schedule	56.6%	Hard
# 1465
# Maximum Area of a Piece of Cake After Horizontal and Vertical Cuts	33.8%	Medium
# 1010
# Pairs of Songs With Total Durations Divisible by 60	50.7%	Medium
# 1192
# Critical Connections in a Network	50.3%	Hard
# 1152
# Analyze User Website Visit Pattern
# 43.1%	Medium
# 146
# LRU Cache	36.3%	Medium
# 937
# Reorder Data in Log Files	54.8%	Easy
# 572
# Subtree of Another Tree	44.6%	Easy
# 547
# Number of Provinces	60.8%	Medium
# 200
# Number of Islands	49.6%	Medium
# 472
# Concatenated Words	43.7%	Hard
# 957
# Prison Cells After N Days	40.1%	Medium
# 973
# K Closest Points to Origin	64.7%	Medium
# 127
# Word Ladder	32.2%	Hard
# 323
# Number of Connected Components in an Undirected Graph
# 58.2%	Medium
# 221
# Maximal Square	39.6%	Medium
# 460
# LFU Cache	36.5%	Hard
# 1710
# Maximum Units on a Truck	69.8%	Easy
# 138
# Copy List with Random Pointer	41.5%	Medium
# 994
# Rotting Oranges	49.6%	Medium
# 1648
# Sell Diminishing-Valued Colored Balls	30.6%	Medium
# 23
# Merge k Sorted Lists	43.1%	Hard
# 295
# Find Median from Data Stream	47.5%	Hard
# 1167
# Minimum Cost to Connect Sticks
# 64.6%	Medium
# 1629
# Slowest Key	59.1%	Easy
# 735
# Asteroid Collision	43.3%	Medium
# 692
# Top K Frequent Words	53.3%	Medium
# 380
# Insert Delete GetRandom O(1)	49.1%	Medium
# 21
# Merge Two Sorted Lists	56.4%	Easy
# 253
# Meeting Rooms II
# 47.1%	Medium
# 1328
# Break a Palindrome	47.8%	Medium
# 210
# Course Schedule II	43.0%	Medium
# 353
# Design Snake Game
# 36.2%	Medium
# 239
# Sliding Window Maximum	44.8%	Hard
# 1120
# Maximum Average Subtree
# 63.9%	Medium
# 1
# Two Sum	46.7%	Easy
# 863
# All Nodes Distance K in Binary Tree	58.2%	Medium
# 140
# Word Break II	35.4%	Hard
# 348
# Design Tic-Tac-Toe
# 55.7%	Medium
# 1597
# Build Binary Expression Tree From Infix Expression
# 59.3%	Hard
# 1135
# Connecting Cities With Minimum Cost
# 59.6%	Medium
# 273
# Integer to English Words	28.3%	Hard
# 103
# Binary Tree Zigzag Level Order Traversal	50.5%	Medium
# 238
# Product of Array Except Self	61.4%	Medium
# 763
# Partition Labels	78.1%	Medium
# 42
# Trapping Rain Water	51.6%	Hard
# 694
# Number of Distinct Islands
# 58.1%	Medium
# 227
# Basic Calculator II	38.8%	Medium
# 56
# Merge Intervals	41.4%	Medium
# 1429
# First Unique Number
# 49.9%	Medium
# 1091
# Shortest Path in Binary Matrix	40.2%	Medium
# 269
# Alien Dictionary
# 33.8%	Hard
# 588
# Design In-Memory File System
# 46.7%	Hard
# 212
# Word Search II	37.5%	Hard
# 240
# Search a 2D Matrix II	45.4%	Medium
# 695
# Max Area of Island	65.2%	Medium
# 1166
# Design File System
# 58.5%	Medium
# 767
# Reorganize String	50.3%	Medium
# 207
# Course Schedule	44.3%	Medium
# 139
# Word Break	41.9%	Medium
# 829
# Consecutive Numbers Sum	39.3%	Hard
# 315
# Count of Smaller Numbers After Self	42.4%	Hard
# 155
# Min Stack	46.8%	Easy
# 33
# Search in Rotated Sorted Array	36.1%	Medium
# 490
# The Maze
# 52.9%	Medium
# 909
# Snakes and Ladders	39.3%	Medium
# 121
# Best Time to Buy and Sell Stock	51.8%	Easy
# 1481
# Least Number of Unique Integers after K Removals	55.9%

# %% [markdown]
# # Amazon 1 year High Freq

# %% [markdown]
# 937
# Reorder Data in Log Files	54.8%	Easy
# 1041
# Robot Bounded In Circle	55.1%	Medium
# 763
# Partition Labels	78.1%	Medium
# 200
# Number of Islands	49.6%	Medium
# 1192
# Critical Connections in a Network	50.3%	Hard
# 1335
# Minimum Difficulty of a Job Schedule	56.6%	Hard
# 692
# Top K Frequent Words	53.3%	Medium
# 146
# LRU Cache	36.3%	Medium
# 819
# Most Common Word	45.5%	Easy
# 1465
# Maximum Area of a Piece of Cake After Horizontal and Vertical Cuts	33.8%	Medium
# 1152
# Analyze User Website Visit Pattern
# 43.1%	Medium
# 1010
# Pairs of Songs With Total Durations Divisible by 60	50.7%	Medium
# 957
# Prison Cells After N Days	40.1%	Medium
# 973
# K Closest Points to Origin	64.7%	Medium
# 994
# Rotting Oranges	49.6%	Medium
# 472
# Concatenated Words	43.7%	Hard
# 127
# Word Ladder	32.2%	Hard
# 138
# Copy List with Random Pointer	41.5%	Medium
# 572
# Subtree of Another Tree	44.6%	Easy
# 23
# Merge k Sorted Lists	43.1%	Hard
# 1167
# Minimum Cost to Connect Sticks
# 64.6%	Medium
# 588
# Design In-Memory File System
# 46.7%	Hard
# 1
# Two Sum	46.7%	Easy
# 295
# Find Median from Data Stream	47.5%	Hard
# 21
# Merge Two Sorted Lists	56.4%	Easy
# 547
# Number of Provinces	60.8%	Medium
# 140
# Word Break II	35.4%	Hard
# 460
# LFU Cache	36.5%	Hard
# 221
# Maximal Square	39.6%	Medium
# 210
# Course Schedule II	43.0%	Medium
# 380
# Insert Delete GetRandom O(1)	49.1%	Medium
# 42
# Trapping Rain Water	51.6%	Hard
# 323
# Number of Connected Components in an Undirected Graph
# 58.2%	Medium
# 1120
# Maximum Average Subtree
# 63.9%	Medium
# 239
# Sliding Window Maximum	44.8%	Hard
# 348
# Design Tic-Tac-Toe
# 55.7%	Medium
# 253
# Meeting Rooms II
# 47.1%	Medium
# 863
# All Nodes Distance K in Binary Tree	58.2%	Medium
# 682
# Baseball Game	67.4%	Easy
# 353
# Design Snake Game
# 36.2%	Medium
# 212
# Word Search II	37.5%	Hard
# 273
# Integer to English Words	28.3%	Hard
# 1429
# First Unique Number
# 49.9%	Medium
# 1268
# Search Suggestions System	64.7%	Medium
# 227
# Basic Calculator II	38.8%	Medium
# 735
# Asteroid Collision	43.3%	Medium
# 139
# Word Break	41.9%	Medium
# 240
# Search a 2D Matrix II	45.4%	Medium
# 5
# Longest Palindromic Substring	30.7%	Medium
# 103
# Binary Tree Zigzag Level Order Traversal	50.5%	Medium
# 1091
# Shortest Path in Binary Matrix	40.2%	Medium
# 238
# Product of Array Except Self	61.4%	Medium
# 269
# Alien Dictionary
# 33.8%	Hard
# 901
# Online Stock Span	61.5%	Medium
# 56
# Merge Intervals	41.4%	Medium
# 1328
# Break a Palindrome	47.8%	Medium
# 909
# Snakes and Ladders	39.3%	Medium
# 79
# Word Search	37.2%	Medium
# 1710
# Maximum Units on a Truck	69.8%	Easy
# 121
# Best Time to Buy and Sell Stock	51.8%	Easy
# 694
# Number of Distinct Islands
# 58.1%	Medium
# 49
# Group Anagrams	59.8%	Medium
# 437
# Path Sum III	48.3%	Medium
# 297
# Serialize and Deserialize Binary Tree	50.3%	Hard
# 815
# Bus Routes	43.6%	Hard
# 503
# Next Greater Element II	58.8%	Medium
# 362
# Design Hit Counter
# 65.5%	Medium
# 733
# Flood Fill	56.0%	Easy
# 1648
# Sell Diminishing-Valued Colored Balls	30.6%	Medium
# 394
# Decode String	53.0%	Medium
# 105
# Construct Binary Tree from Preorder and Inorder Traversal	52.4%	Medium
# 45
# Jump Game II	31.7%	Medium
# 642
# Design Search Autocomplete System
# 46.5%	Hard
# 224
# Basic Calculator	38.3%	Hard
# 33
# Search in Rotated Sorted Array	36.1%	Medium
# 1135
# Connecting Cities With Minimum Cost
# 59.6%	Medium
# 1629
# Slowest Key	59.1%	Easy
# 767
# Reorganize String	50.3%	Medium
# 403
# Frog Jump	41.7%	Hard
# 15
# 3Sum	28.3%	Medium
# 829
# Consecutive Numbers Sum	39.3%	Hard
# 185
# Department Top Three Salaries	39.9%	Hard
# 126
# Word Ladder II	23.8%	Hard
# 12
# Integer to Roman	57.1%	Medium
# 165
# Compare Version Numbers	30.7%	Medium
# 76
# Minimum Window Substring	36.2%	Hard
# 4
# Median of Two Sorted Arrays	31.4%	Hard
# 399
# Evaluate Division	54.6%	Medium
# 188
# Best Time to Buy and Sell Stock IV	30.1%	Hard
# 1011
# Capacity To Ship Packages Within D Days	59.9%	Medium
# 155
# Min Stack	46.8%	Easy
# 123
# Best Time to Buy and Sell Stock III	40.2%	Hard
# 207
# Course Schedule	44.3%	Medium
# 2
# Add Two Numbers	35.7%	Medium
# 25
# Reverse Nodes in k-Group	45.4%	Hard
# 1597
# Build Binary Expression Tree From Infix Expression
# 59.3%	Hard
# 3
# Longest Substring Without Repeating Characters	31.6%	Medium
# 1155
# Number of Dice Rolls With Target Sum	47.6%	Medium
# 74
# Search a 2D Matrix	38.1%	Medium
# 895
# Maximum Frequency Stack	63.3%	Hard
# 726
# Number of Atoms	51.0%	Hard
# 490
# The Maze
# 52.9%	Medium
# 721
# Accounts Merge	52.3%	Medium
# 17
# Letter Combinations of a Phone Number	49.9%	Medium
# 1520
# Maximum Number of Non-Overlapping Substrings	36.6%	Hard
# 640
# Solve the Equation	42.8%	Medium
# 84
# Largest Rectangle in Histogram	37.4%	Hard
# 992
# Subarrays with K Different Integers	50.9%	Hard
# 347
# Top K Frequent Elements	62.6%	Medium
# 236
# Lowest Common Ancestor of a Binary Tree	49.4%	Medium
# 314
# Binary Tree Vertical Order Traversal
# 47.3%	Medium
# 564
# Find the Closest Palindrome	20.4%	Hard
# 208
# Implement Trie (Prefix Tree)	52.6%	Medium
# 445
# Add Two Numbers II	56.5%	Medium
# 1166
# Design File System
# 58.5%	Medium
# 215
# Kth Largest Element in an Array	58.9%	Medium
# 55
# Jump Game	35.3%	Medium
# 277
# Find the Celebrity
# 44.1%	Medium
# 471
# Encode String with Shortest Length
# 49.7%	Hard
# 315
# Count of Smaller Numbers After Self	42.4%	Hard
# 706
# Design HashMap	64.1%	Easy
# 209
# Minimum Size Subarray Sum	39.8%	Medium
# 20
# Valid Parentheses	40.0%	Easy
# 1000
# Minimum Cost to Merge Stones	40.5%	Hard
# 1293
# Shortest Path in a Grid with Obstacles Elimination	43.1%	Hard
# 99
# Recover Binary Search Tree	42.8%	Hard
# 695
# Max Area of Island	65.2%	Medium
# 199
# Binary Tree Right Side View	56.6%	Medium
# 134
# Gas Station	41.6%	Medium
# 211
# Design Add and Search Words Data Structure	40.6%	Medium
# 135
# Candy	33.3%	Hard
# 322
# Coin Change	37.7%	Medium
# 1229
# Meeting Scheduler
# 54.4%	Medium
# 36
# Valid Sudoku	50.9%	Medium
# 688
# Knight Probability in Chessboard	50.3%	Medium
# 518
# Coin Change 2	52.1%	Medium
# 1236
# Web Crawler
# 64.7%	Medium
# 987
# Vertical Order Traversal of a Binary Tree	39.0%	Hard
# 410
# Split Array Largest Sum	46.7%	Hard
# 449
# Serialize and Deserialize BST	54.3%	Medium
# 72
# Edit Distance	47.1%	Hard
# 286
# Walls and Gates
# 57.0%	Medium
# 681
# Next Closest Time
# 46.0%	Medium
# 317
# Shortest Distance from All Buildings
# 42.9%	Hard
# 291
# Word Pattern II
# 44.4%	Medium
# 489
# Robot Room Cleaner
# 73.0%	Hard
# 53
# Maximum Subarray	47.9%	Easy
# 261
# Graph Valid Tree
# 43.4%	Medium
# 1360
# Number of Days Between Two Dates	46.5%	Easy
# 128
# Longest Consecutive Sequence	46.5%	Hard
# 1481
# Least Number of Unique Integers after K Removals	55.9%	Medium
# 46
# Permutations	67.1%	Medium
# 1106
# Parsing A Boolean Expression	59.4%	Hard
# 636
# Exclusive Time of Functions	55.1%	Medium
# 496
# Next Greater Element I	65.9%	Easy
# 205
# Isomorphic Strings	40.6%	Easy
# 335
# Self Crossing	28.8%	Hard
# 715
# Range Module	40.8%	Hard
# 1031
# Maximum Sum of Two Non-Overlapping Subarrays	59.0%	Medium
# 117
# Populating Next Right Pointers in Each Node II	42.4%	Medium
# 388
# Longest Absolute File Path	43.2%	Medium
# 124
# Binary Tree Maximum Path Sum	35.7%	Hard
# 1405
# Longest Happy String	52.6%	Medium
# 854
# K-Similar Strings	38.8%	Hard
# 1156
# Swap For Longest Repeated Character Substring	47.1%	Medium
# 54
# Spiral Matrix	36.5%	Medium
# 1430
# Check If a String Is a Valid Sequence from Root to Leaves Path in a Binary Tree
# 45.2%	Medium
# 1139
# Largest 1-Bordered Square	48.7%	Medium
# 454
# 4Sum II	54.7%	Medium
# 98
# Validate Binary Search Tree	28.9%	Medium
# 41
# First Missing Positive	34.0%	Hard
# 980
