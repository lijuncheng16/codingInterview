# %% [markdown]
# 	22
# Generate Parentheses	65.8%	Medium
# 10
# Regular Expression Matching	27.5%	Hard
# 79
# Word Search	37.2%	Medium
# 140
# Word Break II	35.4%	Hard
# 37
# Sudoku Solver	47.1%	Hard
# 17
# Letter Combinations of a Phone Number	49.9%	Medium
# 212
# Word Search II	37.5%	Hard
# 39
# Combination Sum	59.8%	Medium
# 51
# N-Queens	50.3%	Hard
# 44
# Wildcard Matching	25.5%	Hard
# 46
# Permutations	67.1%	Medium
# 211
# Design Add and Search Words Data Structure	40.6%	Medium
# 126
# Word Ladder II	23.8%	Hard
# 526
# Beautiful Arrangement	62.1%	Medium
# 78
# Subsets	65.7%	Medium
# 1239
# Maximum Length of a Concatenated String with Unique Characters	49.9%	Medium
# 93
# Restore IP Addresses	37.9%	Medium
# 131
# Palindrome Partitioning	52.7%	Medium
# 797
# All Paths From Source to Target	78.6%	Medium
# 306
# Additive Number	29.7%	Medium
# 980
# Unique Paths III	77.0%	Hard
# 1219
# Path with Maximum Gold	65.9%	Medium
# 1659
# Maximize Grid Happiness	35.6%	Hard
# 1240
# Tiling a Rectangle with the Fewest Squares	52.8%	Hard
# 1641
# Count Sorted Vowel Strings	75.6%	Medium
# 1215
# Stepping Numbers
# 43.5%	Medium
# 60
# Permutation Sequence	39.6%	Hard
# 89
# Gray Code	50.7%	Medium
# 90
# Subsets II	49.2%	Medium
# 47
# Permutations II	49.8%	Medium
# 40
# Combination Sum II	50.4%	Medium
# 1088
# Confusing Number II
# 45.6%	Hard
# 425
# Word Squares
# 50.3%	Hard
# 77
# Combinations	58.0%	Medium
# 351
# Android Unlock Patterns
# 49.8%	Medium
