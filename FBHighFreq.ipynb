# %% [markdown]
#  	#	Title	Acceptance	Difficulty	Frequency
# 1249
# Minimum Remove to Make Valid Parentheses	64.2%	Medium
# 1428
# Leftmost Column with at Least a One
# 49.5%	Medium
# 953
# Verifying an Alien Dictionary	52.4%	Easy
# 973
# K Closest Points to Origin	64.7%	Medium
# 680
# Valid Palindrome II	37.1%	Easy
# 1570
# Dot Product of Two Sparse Vectors
# 91.2%	Medium
# 560
# Subarray Sum Equals K	43.7%	Medium
# 238
# Product of Array Except Self	61.4%	Medium
# 415
# Add Strings	48.5%	Easy
# 67
# Add Binary	47.3%	Easy
# 124
# Binary Tree Maximum Path Sum	35.7%	Hard
# 211
# Design Add and Search Words Data Structure	40.6%	Medium
# 269
# Alien Dictionary
# 33.8%	Hard
# 199
# Binary Tree Right Side View	56.6%	Medium
# 426
# Convert Binary Search Tree to Sorted Doubly Linked List
# 61.6%	Medium
# 938
# Range Sum of BST	83.2%	Easy
# 56
# Merge Intervals	41.4%	Medium
# 301
# Remove Invalid Parentheses	44.9%	Hard
# 273
# Integer to English Words	28.3%	Hard
# 125
# Valid Palindrome	38.6%	Easy
# 528
# Random Pick with Weight	44.8%	Medium
# 987
# Vertical Order Traversal of a Binary Tree	39.0%	Hard
# 158
# Read N Characters Given Read4 II - Call multiple times
# 37.4%	Hard
# 215
# Kth Largest Element in an Array	58.9%	Medium
# 986
# Interval List Intersections	68.5%	Medium
# 29
# Divide Two Integers	16.9%	Medium
# 721
# Accounts Merge	52.3%	Medium
# 636
# Exclusive Time of Functions	55.1%	Medium
# 278
# First Bad Version	37.9%	Easy
# 827
# Making A Large Island	47.3%	Hard
# 297
# Serialize and Deserialize Binary Tree	50.3%	Hard
# 65
# Valid Number	16.1%	Hard
# 173
# Binary Search Tree Iterator	60.7%	Medium
# 523
# Continuous Subarray Sum	24.8%	Medium
# 270
# Closest Binary Search Tree Value
# 50.4%	Easy
# 621
# Task Scheduler	52.3%	Medium
# 50
# Pow(x, n)	31.1%	Medium
# 1539
# Kth Missing Positive Number	54.8%	Easy
# 398
# Random Pick Index	58.4%	Medium
# 236
# Lowest Common Ancestor of a Binary Tree	49.4%	Medium
# 543
# Diameter of Binary Tree	49.5%	Easy
# 249
# Group Shifted Strings
# 58.5%	Medium
# 42
# Trapping Rain Water	51.6%	Hard
# 1650
# Lowest Common Ancestor of a Binary Tree III
# 76.7%	Medium
# 339
# Nested List Weight Sum
# 76.9%	Medium
# 863
# All Nodes Distance K in Binary Tree	58.2%	Medium
# 1762
# Buildings With an Ocean View
# 80.8%	Medium
# 88
# Merge Sorted Array	40.9%	Easy
# 140
# Word Break II	35.4%	Hard
# 133
# Clone Graph	39.9%	Medium
# 31
# Next Permutation	33.9%	Medium
# 139
# Word Break	41.9%	Medium
# 340
# Longest Substring with At Most K Distinct Characters
# 45.7%	Medium
# 489
# Robot Room Cleaner
# 73.0%	Hard
# 34
# Find First and Last Position of Element in Sorted Array	37.5%	Medium
# 246
# Strobogrammatic Number
# 46.5%	Easy
# 708
# Insert into a Sorted Circular Linked List
# 32.7%	Medium
# 266
# Palindrome Permutation
# 62.7%	Easy
# 1382
# Balance a Binary Search Tree	76.1%	Medium
# 203
# Remove Linked List Elements	39.5%	Easy
# 76
# Minimum Window Substring	36.2%	Hard
# 958
# Check Completeness of a Binary Tree	52.5%	Medium
# 71
# Simplify Path	34.9%	Medium
# 282
# Expression Add Operators	36.9%	Hard
# 317
# Shortest Distance from All Buildings
# 42.9%	Hard
# 825
# Friends Of Appropriate Ages	44.3%	Medium
# 10
# Regular Expression Matching	27.5%	Hard
# 658
# Find K Closest Elements	42.3%	Medium
# 785
# Is Graph Bipartite?	48.7%	Medium
# 138
# Copy List with Random Pointer	41.5%	Medium
# 691
# Stickers to Spell Word	45.2%	Hard
# 1209
# Remove All Adjacent Duplicates in String II	57.8%	Medium
# 146
# LRU Cache	36.3%	Medium
# 977
# Squares of a Sorted Array	71.8%	Easy
# 157
# Read N Characters Given Read4
# 37.7%	Easy
# 43
# Multiply Strings	35.1%	Medium
# 314
# Binary Tree Vertical Order Traversal
# 47.3%	Medium
# 498
# Diagonal Traverse	50.5%	Medium
# 23
# Merge k Sorted Lists	43.1%	Hard
# 1047
# Remove All Adjacent Duplicates In String	71.3%	Easy
# 247
# Strobogrammatic Number II
# 48.8%	Medium
# 1053
# Previous Permutation With One Swap	51.3%	Medium
# 1233
# Remove Sub-Folders from the Filesystem	62.5%	Medium
# 670
# Maximum Swap	45.3%	Medium
# 163
# Missing Ranges
# 27.4%	Easy
# 896
# Monotonic Array	57.9%	Easy
# 8
# String to Integer (atoi)	15.7%	Medium
# 515
# Find Largest Value in Each Tree Row	62.4%	Medium
# 341
# Flatten Nested List Iterator	55.3%	Medium
# 1757
# Recyclable and Low Fat Products
# 95.5%	Easy
# 536
# Construct Binary Tree from String
# 52.2%	Medium
# 1004
# Max Consecutive Ones III	60.9%	Medium
# 921
# Minimum Add to Make Parentheses Valid	75.0%	Medium
# 438
# Find All Anagrams in a String	45.2%	Medium
# 295
# Find Median from Data Stream	47.5%	Hard
# 347
# Top K Frequent Elements	62.6%	Medium
# 1216
# Valid Palindrome III
# 50.1%	Hard
# 127
# Word Ladder	32.2%	Hard
# 616
# Add Bold Tag in String
# 44.9%	Medium
# 1060
# Missing Element in Sorted Array
# 54.8%	Medium
# 875
# Koko Eating Bananas	53.5%	Medium
# 752
# Open the Lock	53.0%	Medium
# 525
# Contiguous Array	43.6%	Medium
# 283
# Move Zeroes	58.7%	Easy
# 311
# Sparse Matrix Multiplication
# 64.2%	Medium
# 378
# Kth Smallest Element in a Sorted Matrix	56.5%	Medium
# 333
# Largest BST Subtree
# 38.3%	Medium
# 380
# Insert Delete GetRandom O(1)	49.1%	Medium
# 33
# Search in Rotated Sorted Array	36.1%	Medium
# 1361
# Validate Binary Tree Nodes	43.3%	Medium
# 1213
# Intersection of Three Sorted Arrays
# 79.5%	Easy
# 162
# Find Peak Element	44.1%	Medium
# 78
# Subsets	65.7%	Medium
# 739
# Daily Temperatures	64.8%	Medium

# %% [markdown]
# # FB 1 year

# %% [markdown]
# 	1249
# Minimum Remove to Make Valid Parentheses	64.2%	Medium
# 953
# Verifying an Alien Dictionary	52.4%	Easy
# 1428
# Leftmost Column with at Least a One
# 49.5%	Medium
# 973
# K Closest Points to Origin	64.7%	Medium
# 680
# Valid Palindrome II	37.1%	Easy
# 560
# Subarray Sum Equals K	43.7%	Medium
# 238
# Product of Array Except Self	61.4%	Medium
# 415
# Add Strings	48.5%	Easy
# 273
# Integer to English Words	28.3%	Hard
# 67
# Add Binary	47.3%	Easy
# 269
# Alien Dictionary
# 33.8%	Hard
# 211
# Design Add and Search Words Data Structure	40.6%	Medium
# 199
# Binary Tree Right Side View	56.6%	Medium
# 301
# Remove Invalid Parentheses	44.9%	Hard
# 1570
# Dot Product of Two Sparse Vectors
# 91.2%	Medium
# 158
# Read N Characters Given Read4 II - Call multiple times
# 37.4%	Hard
# 124
# Binary Tree Maximum Path Sum	35.7%	Hard
# 938
# Range Sum of BST	83.2%	Easy
# 523
# Continuous Subarray Sum	24.8%	Medium
# 215
# Kth Largest Element in an Array	58.9%	Medium
# 297
# Serialize and Deserialize Binary Tree	50.3%	Hard
# 125
# Valid Palindrome	38.6%	Easy
# 636
# Exclusive Time of Functions	55.1%	Medium
# 987
# Vertical Order Traversal of a Binary Tree	39.0%	Hard
# 278
# First Bad Version	37.9%	Easy
# 173
# Binary Search Tree Iterator	60.7%	Medium
# 528
# Random Pick with Weight	44.8%	Medium
# 65
# Valid Number	16.1%	Hard
# 986
# Interval List Intersections	68.5%	Medium
# 56
# Merge Intervals	41.4%	Medium
# 282
# Expression Add Operators	36.9%	Hard
# 270
# Closest Binary Search Tree Value
# 50.4%	Easy
# 29
# Divide Two Integers	16.9%	Medium
# 721
# Accounts Merge	52.3%	Medium
# 398
# Random Pick Index	58.4%	Medium
# 426
# Convert Binary Search Tree to Sorted Doubly Linked List
# 61.6%	Medium
# 438
# Find All Anagrams in a String	45.2%	Medium
# 670
# Maximum Swap	45.3%	Medium
# 621
# Task Scheduler	52.3%	Medium
# 249
# Group Shifted Strings
# 58.5%	Medium
# 88
# Merge Sorted Array	40.9%	Easy
# 543
# Diameter of Binary Tree	49.5%	Easy
# 339
# Nested List Weight Sum
# 76.9%	Medium
# 50
# Pow(x, n)	31.1%	Medium
# 34
# Find First and Last Position of Element in Sorted Array	37.5%	Medium
# 340
# Longest Substring with At Most K Distinct Characters
# 45.7%	Medium
# 133
# Clone Graph	39.9%	Medium
# 140
# Word Break II	35.4%	Hard
# 314
# Binary Tree Vertical Order Traversal
# 47.3%	Medium
# 42
# Trapping Rain Water	51.6%	Hard
# 827
# Making A Large Island	47.3%	Hard
# 1060
# Missing Element in Sorted Array
# 54.8%	Medium
# 785
# Is Graph Bipartite?	48.7%	Medium
# 825
# Friends Of Appropriate Ages	44.3%	Medium
# 139
# Word Break	41.9%	Medium
# 708
# Insert into a Sorted Circular Linked List
# 32.7%	Medium
# 31
# Next Permutation	33.9%	Medium
# 236
# Lowest Common Ancestor of a Binary Tree	49.4%	Medium
# 23
# Merge k Sorted Lists	43.1%	Hard
# 317
# Shortest Distance from All Buildings
# 42.9%	Hard
# 1026
# Maximum Difference Between Node and Ancestor	69.7%	Medium
# 76
# Minimum Window Substring	36.2%	Hard
# 689
# Maximum Sum of 3 Non-Overlapping Subarrays	47.3%	Hard
# 896
# Monotonic Array	57.9%	Easy
# 958
# Check Completeness of a Binary Tree	52.5%	Medium
# 227
# Basic Calculator II	38.8%	Medium
# 311
# Sparse Matrix Multiplication
# 64.2%	Medium
# 658
# Find K Closest Elements	42.3%	Medium
# 71
# Simplify Path	34.9%	Medium
# 138
# Copy List with Random Pointer	41.5%	Medium
# 863
# All Nodes Distance K in Binary Tree	58.2%	Medium
# 766
# Toeplitz Matrix	65.9%	Easy
# 146
# LRU Cache	36.3%	Medium
# 43
# Multiply Strings	35.1%	Medium
# 333
# Largest BST Subtree
# 38.3%	Medium
# 616
# Add Bold Tag in String
# 44.9%	Medium
# 1539
# Kth Missing Positive Number	54.8%	Easy
# 347
# Top K Frequent Elements	62.6%	Medium
# 1216
# Valid Palindrome III
# 50.1%	Hard
# 157
# Read N Characters Given Read4
# 37.7%	Easy
# 304
# Range Sum Query 2D - Immutable	41.2%	Medium
# 1233
# Remove Sub-Folders from the Filesystem	62.5%	Medium
# 10
# Regular Expression Matching	27.5%	Hard
# 378
# Kth Smallest Element in a Sorted Matrix	56.5%	Medium
# 8
# String to Integer (atoi)	15.7%	Medium
# 163
# Missing Ranges
# 27.4%	Easy
# 921
# Minimum Add to Make Parentheses Valid	75.0%	Medium
# 463
# Island Perimeter	66.8%	Easy
# 266
# Palindrome Permutation
# 62.7%	Easy
# 380
# Insert Delete GetRandom O(1)	49.1%	Medium
# 1197
# Minimum Knight Moves
# 37.5%	Medium
# 977
# Squares of a Sorted Array	71.8%	Easy
# 1424
# Diagonal Traverse II	46.3%	Medium
# 203
# Remove Linked List Elements	39.5%	Easy
# 246
# Strobogrammatic Number
# 46.5%	Easy
# 33
# Search in Rotated Sorted Array	36.1%	Medium
# 1209
# Remove All Adjacent Duplicates in String II	57.8%	Medium
# 78
# Subsets	65.7%	Medium
# 109
# Convert Sorted List to Binary Search Tree	50.7%	Medium
# 678
# Valid Parenthesis String	31.8%	Medium
# 1004
# Max Consecutive Ones III	60.9%	Medium
# 489
# Robot Room Cleaner
# 73.0%	Hard
# 767
# Reorganize String	50.3%	Medium
# 381
# Insert Delete GetRandom O(1) - Duplicates allowed	35.0%	Hard
# 695
# Max Area of Island	65.2%	Medium
# 939
# Minimum Area Rectangle	52.2%	Medium
# 1650
# Lowest Common Ancestor of a Binary Tree III
# 76.7%	Medium
# 791
# Custom Sort String	65.9%	Medium
# 253
# Meeting Rooms II
# 47.1%	Medium
# 432
# All O`one Data Structure	33.2%	Hard
# 1047
# Remove All Adjacent Duplicates In String	71.3%	Easy
# 127
# Word Ladder	32.2%	Hard
# 858
# Mirror Reflection	59.6%	Medium
# 1762
# Buildings With an Ocean View
# 80.8%	Medium
# 247
# Strobogrammatic Number II
# 48.8%	Medium
# 934
# Shortest Bridge	49.9%	Medium
# 162
# Find Peak Element	44.1%	Medium
# 525
# Contiguous Array	43.6%	Medium
# 200
# Number of Islands	49.6%	Medium
# 1498
# Number of Subsequences That Satisfy the Given Sum Condition	38.9%	Medium
# 1242
# Web Crawler Multithreaded
# 47.7%	Medium
# 348
# Design Tic-Tac-Toe
# 55.7%	Medium
# 498
# Diagonal Traverse	50.5%	Medium
# 114
# Flatten Binary Tree to Linked List	52.4%	Medium
# 515
# Find Largest Value in Each Tree Row	62.4%	Medium
# 1382
# Balance a Binary Search Tree	76.1%	Medium
# 983
# Minimum Cost For Tickets	62.8%	Medium
# 1213
# Intersection of Three Sorted Arrays
# 79.5%	Easy
# 129
# Sum Root to Leaf Numbers	51.3%	Medium
# 772
# Basic Calculator III
# 44.1%	Hard
# 408
# Valid Word Abbreviation
# 31.5%	Easy
# 1439
# Find the Kth Smallest Sum of a Matrix With Sorted Rows	60.3%	Hard
# 341
# Flatten Nested List Iterator	55.3%	Medium
# 419
# Battleships in a Board	71.3%	Medium
# 92
# Reverse Linked List II	40.8%	Medium
# 536
# Construct Binary Tree from String
# 52.2%	Medium
# 39
# Combination Sum	59.8%	Medium
# 283
# Move Zeroes	58.7%	Easy
# 548
# Split Array with Equal Sum
# 48.3%	Medium
# 844
# Backspace String Compare	47.2%	Easy
# 400
# Nth Digit	32.4%	Medium
# 19
# Remove Nth Node From End of List	35.9%	Medium
# 295
# Find Median from Data Stream	47.5%	Hard
# 480
# Sliding Window Median	38.9%	Hard
# 1361
# Validate Binary Tree Nodes	43.3%	Medium
# 1094
# Car Pooling	59.6%	Medium
# 15
# 3Sum	28.3%	Medium
# 93
# Restore IP Addresses	37.9%	Medium
# 540
# Single Element in a Sorted Array	57.9%	Medium
# 691
# Stickers to Spell Word	45.2%	Hard
# 839
# Similar String Groups	41.7%	Hard
# 875
# Koko Eating Bananas	53.5%	Medium
# 529
# Minesweeper	61.5%	Medium
# 724
# Find Pivot Index	46.1%	Easy
# 207
# Course Schedule
