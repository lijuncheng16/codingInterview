# %%
Welcome to Facebook!

This is just a simple shared plaintext pad, with no execution capabilities.

When you know what language you would like to use for your interview,
simply choose it from the dropdown in the top bar.

Enjoy your interview!

# data is d-dim floats 
#List[List[float]] Nxd

data = np.array([[1, 2],
              [1.5, 1.8],
              [5, 8 ],
              [8, 8],
              [1, 0.6],
              [9,11]])

# initialize k centroids

# while(True)
#    1. Assign points to nearest cluster
#    2. Recalculate centroids
import numpy as np

def k_means(k, data):
    #Initilization
    max_iter = 100
    centroids = {}
    isDone = True 
    epsilon = 0.01
    
    # initialize centroid
    
    for j in range(k):
        centroids[j] = data[j]
        
    # updates for each iteration keep the loop going
    for i in range(max_iter):
        clusters = {}
        for i range(k):
            clusters[i] = []
        #1. Assign points to nearest cluster
        for feat in data:
            # list[floats] distance[i] 
            distances = [np.linalg.norm(feat - centroids[centroid]) for centroid in centroids]
#             distances = [eucli_dist(feat, centroid) for centroid in centroids] # calculate distance between feat to centroids
            cluster = distances.index(min(distance))
            clusters[cluster].append(feat)
#             assignment = distances.index(min(distance))
#             assignments[assignmet].append(feat)
        
     #2. Recalculate centroids
        previous = centroids
        for cluster in clusters:
            centroids[cluster] = np.avg(clusters[cluster], axis=0)
            
#         for assignment in assignments:
#             centroids[assignment] = np.avg(assigments[assignment], axis =0)
    
        for centroid in centriods:
            prev_centroid = previous[centroid]
            curr_centroid = centroids[centroid]
            # check converge
            if np.sum((curr_centroid-prev_centriod)/prev_centroid *100)> epsilon: 
#             if (curr_centroid - prev_centriod)/curr_centriod < epsilon:
                isDone = False 
        if isDone:
            break
    

# distance fuction
def eucli_dist(feat1, feat2):
    sq_dist = 0
    for i in range(len(feat1)):
        sq_dist += (feat1[i] - feat2[i])**2
    sqrt_dist = sqrt(sq_dist)
    return sqrt_dist

# %%
def predict(data):
    distances = [np.linalg.norm(data - centroids[centroid]) for centroid in centroids]
    cluster = distances.index(min(distances))
    return cluster
